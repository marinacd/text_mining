# %% [raw]
# pip install chemlistem

# %% [raw]
# pip install virtualenv

# %% [markdown]
# # METABOLISTM

# %%
import metabolistem_model
json_path = 'C:/Users/pauca/OneDrive/Escritorio/Marina TFG/TMpipeline/MetaboliteNER-main/Models/metabolistem/metabolistem.json'
model_path = 'C:/Users/pauca/OneDrive/Escritorio/Marina TFG/TMpipeline/MetaboliteNER-main/Models/metabolistem/metabolistem.h5'

mm = metabolistem_model.MetaboListem()
mm.load(json_path,model_path)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1137 > 512). Running this sequence through the model will result in indexing errors
# Auxillary information read at 2022-07-04 20:10:12.153384
# Model read at 2022-07-04 20:10:13.408213

# %% [markdown]
# Running Metabolistem with gold standard corpus:

# %%
gold = 'C:/Users/pauca/OneDrive/Escritorio/Marina TFG/TMpipeline/MetaboliteNER-main/Corpus/GoldStandard.txt'

# %%
import csv
textt = list(csv.reader(open(gold, encoding = "utf-8"), delimiter='\t'))
mm.process(textt[0][2])
# Out:
# 1/1 [==============================] - 2s 2s/step
# [(158, 168, 'creatinine'), (173, 180, 'glucose')]

# %%
out_metabolistm = []

for l in textt:
    out_metabolistm.append(mm.process(l[2]))
# Out:
# ...
# 1/1 [==============================] - 0s 21ms/step
# ...
# ...
# 1/1 [==============================] - 0s 20ms/step

# %%
print(out_metabolistm[0:10])
# Out:
# [(148, 158, 'creatinine'), (163, 167, 'urea'), (253, 260, 'glucose'), (329, 336, 'lactate'), (341, 348, 'acetate'), (366, 373, 'glucose')]

# %%
save = "C:/Users/pauca/OneDrive/Escritorio/Marina TFG/TMpipeline/MetaboliteNER-main/results/GoldStandard/metabolistm.csv"

# %%
with open(save, "w", encoding = "utf-8") as f:
    write = csv.writer(f)
    write.writerows(out)

# %% [markdown]
# # TABOLISTM

# %%
import tabolistem_model
json_path= 'C:/Users/pauca/OneDrive/Escritorio/Marina TFG/TMpipeline/MetaboliteNER-main/TABoLiSTM/tabolistem.json'
weight_path= 'C:/Users/pauca/OneDrive/Escritorio/Marina TFG/TMpipeline/MetaboliteNER-main/TABoLiSTM/tabolistem_weights'    ## no suffix

tm = tabolistem_model.TaboListem()
tm.load(json_path,weight_path)
# Out:
# Loading model...
# Token indices sequence length is longer than the specified maximum sequence length for this model (1137 > 512). Running this sequence through the model will result in indexing errors
# Auxillary information read at 2022-07-04 22:21:37.968420
# All PyTorch model weights were used when initializing TFBertForTokenClassification.
#
# Some weights or buffers of the TF 2.0 model TFBertForTokenClassification were not initialized from the PyTorch model and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Model initialised at  2022-07-04 22:21:50.349084
# Model established.
# Model weight loaded at  2022-07-04 22:21:53.350285

# %%
out_tabolistm = []

for l in textt:
    out_tabolistm.append(tm.process(l[2]))
# Out:
# ...
# 1/1 [==============================] - 0s 224ms/step
# ...
# ...
# 1/1 [==============================] - 0s 134ms/step

# %%
print(out_tabolistm[0:10])

# %%
save = "C:/Users/pauca/OneDrive/Escritorio/Marina TFG/TMpipeline/MetaboliteNER-main/results/GoldStandard/tabolistm.csv"
with open(save, "w", encoding = "utf-8") as f:
    write = csv.writer(f)
    write.writerows(out_tabolistm)

# %% [markdown]
# Generating dataset?

# %%
pip install spacy
# Out:
# ...
#   Attempting uninstall: smart-open
#     Found existing installation: smart-open 5.1.0
#     Uninstalling smart-open-5.1.0:Note: you may need to restart the kernel to use updated packages.
#       Successfully uninstalled smart-open-5.1.0
# ...

# %%
pmc = "C:/Users/pauca/OneDrive/Escritorio/Marina TFG/Marina TFG/"
t = "results"
    
# %run generate_corpus.py -b pmc -t t -n "output" -m "MetaboliteNames.txt" -r "RegexList_RuleBasedAnnotation.docx" -e "ExclusionList_RuleBasedAnnotation.txt"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\OneDrive\Escritorio\Marina TFG\TMpipeline\MetaboliteNER-main\generate_corpus.py:291, in <module>
#     289 df_output = pd.DataFrame()
#     290 df_text_output = pd.DataFrame()
# --> 291 json_file_list = os.listdir(json_dir)
#     293 # Read metabolite names
#     294 metabolite_names = pd.read_csv(
#     295     metabolite_names_dir, delimiter='\t', keep_default_na=False)
#
# FileNotFoundError: [WinError 3] El sistema no puede encontrar la ruta especificada: 'pmc'
